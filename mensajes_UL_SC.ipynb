# %%
import re
import pandas as pd
import numpy as np
import os
import glob
from pathlib import Path
import shutil

# %%
dia = '20260601'

# %%
origen = r"Z:/01 base_datos/41 Informe Diario CCZ/FMS 2025/SMART OPERATOR/mensajes ul-SC smart operator/mensajes ul-SC dia actual"

# Listar solo archivos CSV del día
archivos_csv = [
    os.path.join(origen, f) 
    for f in os.listdir(origen) 
    if f.endswith(".csv") and dia in f
]

print(f"Archivos encontrados: {len(archivos_csv)}")

# Unir todos en un solo DataFrame
df_final = pd.concat(
    (pd.read_csv(f, sep=';', encoding='latin1', skiprows=1, low_memory=False) for f in archivos_csv),
    ignore_index=True
)
# Out:
# Archivos encontrados: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 13
#      10 print(f"Archivos encontrados: {len(archivos_csv)}")
#      12 # Unir todos en un solo DataFrame
# ---> 13 df_final = pd.concat(
#      14     (pd.read_csv(f, sep=';', encoding='latin1', skiprows=1, low_memory=False) for f in archivos_csv),
#      15     ignore_index=True
#      16 )
#
# File c:\Users\Jonny Villareal\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
# ...

# %%
# Guardar el consolidado en la MISMA CARPETA
archivo_salida = os.path.join(origen, f"{dia}_CONSOLIDADO_ULSC.csv")

df_final.to_csv(archivo_salida, index=False, sep=';')

print(f"✅ Consolidado creado: {archivo_salida}")
# Out:
# ✅ Consolidado creado: Z:/01 base_datos/41 Informe Diario CCZ/FMS 2025/SMART OPERATOR/mensajes ul-SC smart operator/mensajes ul-SC dia actual\20260429_CONSOLIDADO_ULSC.csv

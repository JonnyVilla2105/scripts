# %%
import pandas as pd
import numpy as np
import subprocess
import os
from datetime import datetime, timedelta, time, date
import datetime
from datetime import datetime
import locale
import seaborn as sns
import matplotlib.pyplot as plt
import unicodedata
import re

# %% [markdown]
# Base de quejas

# %%
#Importar archivo

quejas = pd.read_excel('C:/Users/Jonny Villareal/OneDrive - Gmovil SAS/Escritorio/Jonny/Control 2026/PQRS_TMSA/quejas_TMSA.xlsx')

quejas.head()
# Out:
#               MECANISMO DE RECEPCION DE LA QUEJA        RADICADO   \
# 0  Correo electronico  Aux. Operaciones Tintal 2          3617737
# 1                                            CRM          3616075
# 2                                            CRM          3629209
# 3                                            CRM          3609297
# 4             Correo electronico Coordinador CCZ  GM-R-2026-06455
#
#   FECHA ASIGNACIÓN FECHA DE VENCIMIENTO   \
# 0       2026-01-13            2026-01-19
# 1       2026-01-09            2026-01-15
# 2       2026-01-09            2026-01-15
# 3       2026-01-09            2026-01-15
# 4       2026-01-26            2026-02-01
#
#                                          DESCRIPCION TIPO DE RADICADO RUTA  \
# 0                    Se genera respuesta por correo             Queja  E25
# 1  El servicio de SITP de la ruta 740 que sale de...          Reclamo  740
# 2  Usuario se comunica para informar que la ruta ...          Reclamo  614
# ...

# %%
valores_excluir = [
    'Correo electronico  Aux. Operaciones Tintal 2',
    'Correo electronico Coordinador CCZ',
    'Whats app Diana Ortegon Verbena '
]

quejas = quejas[
    ~quejas['MECANISMO DE RECEPCION DE LA QUEJA'].isin(valores_excluir)
]

quejas.head()
# Out:
#   MECANISMO DE RECEPCION DE LA QUEJA  RADICADO  FECHA ASIGNACIÓN  \
# 1                                CRM    3616075       2026-01-09
# 2                                CRM    3629209       2026-01-09
# 3                                CRM    3609297       2026-01-09
# 6                  Bogotá te escucha  383752026       2026-01-26
# 7                                CRM    3656709       2026-01-26
#
#   FECHA DE VENCIMIENTO                                         DESCRIPCION  \
# 1            2026-01-15  El servicio de SITP de la ruta 740 que sale de...
# 2            2026-01-15  Usuario se comunica para informar que la ruta ...
# 3            2026-01-15  Sr. Jose Igancio, se comunica para informar qu...
# 6            2026-02-01  LAS RUTAS DE BUSES 12, K303, P500. TARDAN DEMA...
# 7            2026-02-01  Usuario se comunica para informar que la ruta ...
#
#   TIPO DE RADICADO   RUTA FECHA DE RESPUESTA   DIAS RESPUESTA    Mes Fecha  \
# ...

# %%
print(quejas['MECANISMO DE RECEPCION DE LA QUEJA'].unique())
# Out:
# ['CRM' 'Bogotá te escucha']

# %%
quejas.to_csv('C:/Users/Jonny Villareal/OneDrive - Gmovil SAS/Escritorio/Jonny/Control 2026/PQRS_TMSA/seguimiento_quejas.csv', index=False, sep=';')
